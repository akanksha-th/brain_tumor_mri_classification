# %%
import matplotlib.pyplot as plt, os, PIL

# %%
tumor_classes = ['glioma', 'meningioma', 'no_tumor', 'pituitary']
dir_name = "C:/Users/aktkr/brain_tumor_mri_classification/.data/train"
count = 0 

for tumor in tumor_classes:
    img_path = os.path.join(dir_name, tumor)
    for files in os.walk(img_path):
        plt.show(files[0])
        break
